# %% [markdown]
# # Analisis Penjualan - Day 2 Python Pandas
# **Nama**: [Isi nama kamu]
# **Tujuan**: Eksplorasi data penjualan menggunakan pandas

# %%
import pandas as pd
import numpy as np

# Load data
df = pd.read_csv('data.csv')
df.head()

# %%
# Info dataset
df.info()

# %%
# Statistik deskriptif
df.describe()

# %%
# Cek nilai yang hilang
df.isnull().sum()

# %% [markdown]
# ### Kesimpulan Sementara
# - Dataset berisi ... baris dan ... kolom
# - Ada ... nilai yang hilang
# - Kolom yang perlu dibersihkan: ...
